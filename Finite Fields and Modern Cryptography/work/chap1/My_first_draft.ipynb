# %%
from sage.all import *
K = NumberField(x**Integer(6) + Integer(40)*x**Integer(3) + Integer(1372), names=('alpha',)); (alpha,) = K._first_ngens(1)
G = K.galois_group()
G
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sage.all import *
# ----> 2 K = NumberField(x**Integer(6) + Integer(40)*x**Integer(3) + Integer(1372), names=('alpha',)); (alpha,) = K._first_ngens(1)
#       3 G = K.galois_group()
#       4 G
#
# NameError: name 'x' is not defined

# %%
from sage.all import *

# %%
K = NumberField(x**Integer(6) + Integer(40)*x**Integer(3) + Integer(1372), names=('alpha',)); (alpha,) = K._first_ngens(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 K = NumberField(x**Integer(6) + Integer(40)*x**Integer(3) + Integer(1372), names=('alpha',)); (alpha,) = K._first_ngens(1)
#
# NameError: name 'x' is not defined

# %%
from sage.all import *
G.order()
G.gens()
f = G.gen(1); f(alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from sage.all import *
# ----> 2 G.order()
#       3 G.gens()
#       4 f = G.gen(1); f(alpha)
#
# NameError: name 'G' is not defined

# %%
from sage.all import *
K = NumberField(x**Integer(3) - Integer(2), names=('alpha',)); (alpha,) = K._first_ngens(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sage.all import *
# ----> 2 K = NumberField(x**Integer(3) - Integer(2), names=('alpha',)); (alpha,) = K._first_ngens(1)
#
# NameError: name 'x' is not defined

# %%
from sage.all import *
K
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from sage.all import *
# ----> 2 K
#
# NameError: name 'K' is not defined

# %%
from sage.all import *
x = Integer(1)
K = NumberField(x**Integer(3) - Integer(2), names=('alpha',)); (alpha,) = K._first_ngens(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/rings/number_field/number_field.py:626, in NumberFieldFactory.create_key_and_extra_args(self, polynomial, name, check, embedding, latex_name, assume_disc_small, maximize_at_primes, structure)
#     625 try:
# --> 626     polynomial = polynomial.polynomial(QQ)
#     627 except (AttributeError, TypeError):
#
# File ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:13068)()
#     494 """
# --> 495 return self.getattr_from_category(name)
#     496
#
# File ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/structure/element.pyx:508, in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:13178)()
#     507     cls = P._abstract_element_class
# --> 508 return getattr_from_other_class(self, cls, name)
#     509
#
# File ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/cpython/getattr.pyx:363, in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:4677)()
#     362     dummy_error_message.name = name
# --> 363     raise AttributeError(dummy_error_message)
#     364 attribute = <object>attr
#
# AttributeError: 'sage.rings.integer.Integer' object has no attribute 'polynomial'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6488/2577430961.py in ?()
#       1 from sage.all import *
#       2 x = Integer(1)
# ----> 3 K = NumberField(x**Integer(3) - Integer(2), names=('alpha',)); (alpha,) = K._first_ngens(1)
#
# ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/rings/number_field/number_field.py in ?(polynomial, name, check, names, embedding, latex_name, assume_disc_small, maximize_at_primes, structure, latex_names, **kwds)
#     546             raise NotImplementedError("Number field with prescribed %s is not implemented" % key)
#     547     if isinstance(polynomial, (list, tuple)):
#     548         return NumberFieldTower(polynomial, names=name, check=check, embeddings=embedding, latex_names=latex_name, assume_disc_small=assume_disc_small, maximize_at_primes=maximize_at_primes, structures=structure)
#     549
# --> 550     return NumberField_version2(polynomial=polynomial, name=name, check=check, embedding=embedding, latex_name=latex_name, assume_disc_small=assume_disc_small, maximize_at_primes=maximize_at_primes, structure=structure)
#
# sage/structure/factory.pyx in ?()
# --> 371 'Could not get source, probably due dynamically evaluated source code.'
#
# ~/miniforge3/envs/sage/lib/python3.12/site-packages/sage/rings/number_field/number_field.py in ?(self, polynomial, name, check, embedding, latex_name, assume_disc_small, maximize_at_primes, structure)
#     624         if not isinstance(polynomial, Polynomial):
#     625             try:
#     626                 polynomial = polynomial.polynomial(QQ)
#     627             except (AttributeError, TypeError):
# --> 628                 raise TypeError("polynomial (=%s) must be a polynomial." % polynomial)
#     629
#     630         # convert polynomial to a polynomial over a field
#     631         polynomial = polynomial.change_ring(polynomial.base_ring().fraction_field())
#
# TypeError: polynomial (=-1) must be a polynomial.

# %%
from sage.all import *
reset('x')
x
x = Integer(1)
x = var('x')
x
x = Integer(1)
x = polygen(QQ, 'x')
x
x = Integer(1)
R = PolynomialRing(QQ, names=('x',)); (x,) = R._first_ngens(1)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from sage.all import *
#       2 reset('x')
# ----> 3 x
#       4 x = Integer(1)
#       5 x = var('x')
#
# NameError: name 'x' is not defined

# %%
from sage.all import *
reset('x')
x = Integer(1)
x = var('x')
x = Integer(1)
x = polygen(QQ, 'x')
x = Integer(1)
R = PolynomialRing(QQ, names=('x',)); (x,) = R._first_ngens(1)

# %%
x
# Out:
# x

# %%
 from sage.all import *
 K = NumberField(x**Integer(6) + Integer(40)*x**Integer(3) + Integer(1372), names=('alpha',)); (alpha,) = K._first_ngens(1)
 G = K.galois_group()
 G
# Out:
# Galois group 6T2 ([3]2) with order 6 of x^6 + 40*x^3 + 1372
